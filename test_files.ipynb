# %%
 # %run create_tables.py
# Out:
# DROP TABLE IF EXISTS staging_events
# DROP TABLE IF EXISTS staging_songs
# DROP TABLE IF EXISTS songplays
# DROP TABLE IF EXISTS users
# DROP TABLE IF EXISTS songs
# DROP TABLE IF EXISTS artists
# DROP TABLE IF EXISTS time
#
# CREATE TABLE staging_events
# (
#     artist VARCHAR,
#     auth VARCHAR,
#     firstName VARCHAR,
#     gender VARCHAR,
#     itemInSession integer,
#     lastName VARCHAR,
#     length DOUBLE PRECISION,
#     level VARCHAR,
#     location VARCHAR,
#     method VARCHAR,
#     page VARCHAR,
#     registration DOUBLE PRECISION,
#     sessionId INTEGER,
#     song VARCHAR,
#     status INTEGER,
#     ts BIGINT,
#     userAgent VARCHAR,
#     userId INTEGER
# )
#
#
# CREATE TABLE staging_songs
# (
#     num_songs BIGINT,
#     artist_id VARCHAR,
#     artist_latitude DOUBLE PRECISION,
#     artist_longitude DOUBLE PRECISION,
#     artist_location VARCHAR,
#     artist_name VARCHAR,
#     song_id VARCHAR,
#     title VARCHAR,
#     duration DOUBLE PRECISION,
#     year INTEGER
# )
#
#
#     CREATE TABLE  IF NOT EXISTS users (
#         user_id BIGINT IDENTITY(1, 1) PRIMARY KEY NOT NULL,
#         first_name VARCHAR NOT NULL,
#         last_name VARCHAR,
#         gender VARCHAR,
#         level VARCHAR
#     );
#
#
#     CREATE TABLE artists (
#     artist_id VARCHAR PRIMARY KEY NOT NULL,
#     name VARCHAR NOT NULL,
#     location VARCHAR,
#     latitude decimal,
#     longitude decimal
#     )
#
#
#     CREATE TABLE songs (
#         song_id VARCHAR PRIMARY KEY NOT NULL,
#         title VARCHAR NOT NULL,
#         artist_id VARCHAR NOT NULL REFERENCES artists (artist_id),
#         year INT,
#         duration decimal
#     );
#
#
#     CREATE TABLE  time (
#         start_time TIMESTAMP PRIMARY KEY NOT NULL,
#         hour INT,
#         day INT,
#         week INT,
#         month INT,
#         year INT,
#         weekday INT
#     )
#
#
# CREATE TABLE songplays
# (
#     song_play_id BIGINT IDENTITY(1, 1) PRIMARY KEY NOT NULL,
#     start_time TIMESTAMP NOT NULL REFERENCES time (start_time),
#     user_id BIGINT NOT NULL  REFERENCES users (user_id),
#     level VARCHAR,
#     song_id VARCHAR REFERENCES songs (song_id),
#     artist_id VARCHAR REFERENCES artists (artist_id),
#     session_id INT,
#     location VARCHAR,
#     user_agent VARCHAR
# )
#
# FIM

# %%
# %run etl.py
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /home/workspace/etl.py in <module>()
#      30
#      31 if __name__ == "__main__":
# ---> 32     main()
#
# /home/workspace/etl.py in main()
#      23     cur = conn.cursor()
#      24
# ---> 25     load_staging_tables(cur, conn)
#      26     insert_tables(cur, conn)
#      27
#
# /home/workspace/etl.py in load_staging_tables(cur, conn)
#       6 def load_staging_tables(cur, conn):
#       7     for query in copy_table_queries:
# ----> 8         cur.execute(query)
#       9         conn.commit()
#      10
#
# InternalError: Load into table 'staging_songs' failed.  Check 'stl_load_errors' system table for details.

# %%
import configparser
import psycopg2

# %%
config = configparser.ConfigParser()
config.read('dwh.cfg')
print(*config['CLUSTER'].values())
# conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
# cur = conn.cursor()
    
# # load_staging_tables(cur, conn)
# # insert_tables(cur, conn)

# conn.close()
# Out:
# 'dwhcluster.cwwlmrbd6tya.us-west-2.redshift.amazonaws.com' dwh dwhuser Passw0rd 5439

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format('dwhuser', 'Passw0rd', 
                                                     'dwhcluster.cwwlmrbd6tya.us-west-2.redshift.amazonaws.com', 5439,'dwh')
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.cwwlmrbd6tya.us-west-2.redshift.amazonaws.com:5439/dwh
# 'Connected: dwhuser@dwh'

# %%
# %sql select * from stl_load_errors
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cwwlmrbd6tya.us-west-2.redshift.amazonaws.com:5439/dwh
# 13 rows affected.
# [(100, 2, 101635, datetime.datetime(2021, 8, 25, 13, 31, 15, 532554), 12747, 145, 's3://udacity-dend/song_data/A/A/A/TRAAACN128F9355673.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AR9Q9YC1187FB5609B","artist_latitude":null,"artist_location":"New Jersey","artist_longitude":null,"artist_name":"Quest_ Pup_ Kevo","dur ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AR9Q9YC1187FB5609B","artist_latitude":null,"artist_location":"New Jersey","artist_longitude":null,"artist_name":"Quest_ Pup_ Kevo","dur ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 3, 101684, datetime.datetime(2021, 8, 25, 13, 57, 0, 793097), 15836, 432, 's3://udacity-dend/song_data/A/A/A/TRAAAEA128F935A30D.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARSVTNL1187B992A91","artist_latitude":51.50632,"artist_location":"London, England","artist_longitude":-0.12714,"artist_name":"Jonathan  ... (727 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARSVTNL1187B992A91"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 2, 101688, datetime.datetime(2021, 8, 25, 13, 58, 5, 417719), 15896, 457, 's3://udacity-dend/song_data/A/A/A/TRAAACN128F9355673.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AR9Q9YC1187FB5609B","artist_latitude":null,"artist_location":"New Jersey","artist_longitude":null,"artist_name":"Quest_ Pup_ Kevo","dur ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AR9Q9YC1187FB5609B"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 4, 101635, datetime.datetime(2021, 8, 25, 13, 31, 15, 532554), 12747, 145, 's3://udacity-dend/song_data/A/A/A/TRAAAEA128F935A30D.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARSVTNL1187B992A91","artist_latitude":51.50632,"artist_location":"London, England","artist_longitude":-0.12714,"artist_name":"Jonathan  ... (727 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARSVTNL1187B992A91","artist_latitude":51.50632,"artist_location":"London, England","artist_longitude":-0.12714,"artist_name":"Jonathan  ... (727 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 5, 101635, datetime.datetime(2021, 8, 25, 13, 31, 15, 532554), 12747, 145, 's3://udacity-dend/song_data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARJNIUY12298900C91","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Adelitas Way","duration":213.942 ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARJNIUY12298900C91","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Adelitas Way","duration":213.942 ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 5, 101684, datetime.datetime(2021, 8, 25, 13, 57, 0, 793097), 15836, 432, 's3://udacity-dend/song_data/A/A/A/TRAAAED128E0783FAB.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARC1IHZ1187FB4E920","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Jamie Cullum","duration":246.987 ... (727 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARC1IHZ1187FB4E920"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 5, 101688, datetime.datetime(2021, 8, 25, 13, 58, 5, 417719), 15896, 457, 's3://udacity-dend/song_data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARJNIUY12298900C91","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Adelitas Way","duration":213.942 ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARJNIUY12298900C91"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 0, 101635, datetime.datetime(2021, 8, 25, 13, 31, 15, 532554), 12747, 145, 's3://udacity-dend/song_data/A/A/A/TRAAAEM128F93347B9.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AREWD471187FB49873","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Son Kite","duration":580.54485," ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AREWD471187FB49873","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Son Kite","duration":580.54485," ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 101684, datetime.datetime(2021, 8, 25, 13, 57, 0, 793097), 15836, 432, 's3://udacity-dend/song_data/A/A/A/TRAAACN128F9355673.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AR9Q9YC1187FB5609B","artist_latitude":null,"artist_location":"New Jersey","artist_longitude":null,"artist_name":"Quest_ Pup_ Kevo","dur ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AR9Q9YC1187FB5609B"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 1, 101688, datetime.datetime(2021, 8, 25, 13, 58, 5, 417719), 15896, 457, 's3://udacity-dend/song_data/A/A/A/TRAAABD128F429CF47.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARMJAGH1187FB546F3","artist_latitude":35.14968,"artist_location":"Memphis, TN","artist_longitude":-90.04892,"artist_name":"The Box Tops ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARMJAGH1187FB546F3"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 6, 101635, datetime.datetime(2021, 8, 25, 13, 31, 15, 532554), 12747, 145, 's3://udacity-dend/song_data/A/A/A/TRAAAED128E0783FAB.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"ARC1IHZ1187FB4E920","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Jamie Cullum","duration":246.987 ... (727 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"ARC1IHZ1187FB4E920","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Jamie Cullum","duration":246.987 ... (727 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 7, 101684, datetime.datetime(2021, 8, 25, 13, 57, 0, 793097), 15836, 432, 's3://udacity-dend/song_data/A/A/A/TRAAAEM128F93347B9.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AREWD471187FB49873","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Son Kite","duration":580.54485," ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AREWD471187FB49873"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0),
#  (100, 7, 101688, datetime.datetime(2021, 8, 25, 13, 58, 5, 417719), 15896, 457, 's3://udacity-dend/song_data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int8      ', '0         ', 0, '{"artist_id":"AR73AIO1187B9AD57B","artist_latitude":37.77916,"artist_location":"San Francisco, CA","artist_longitude":-122.42005,"artist_name":"Weste ... (726 characters truncated) ...                                                                                                                                                      ', '{"artist_id":"AR73AIO1187B9AD57B"                                                                                                                     ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '{', Pos 0, Type: Long                                                         ", 0, 0)]
